# %%
import glance
import skimage as ski
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Create an image

# %%
image = ski.data.coins()

# %% [markdown]
# # View it in web

# %%
glance.in_web(image)

# %% [markdown]
# # View inline

# %%
# Experimental
glance.inline(image)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Glance</title>
#     <style>
#         body {
#             margin: 0;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh;
#             background: #292929;
#             overflow: hidden;
#         }
#         .zoom-container {
#             height: auto;
#             width: 100vw;
#             position: relative;
#             overflow: hidden;
#             background: #000000;
#             box-shadow: 0 0 10px rgba(0,0,0,0.1);
#             cursor: grab;
#         }
#         .zoom-container:active {
#             cursor: grabbing;
#         }
#         #zoomable-image {
#             display: block;
#             max-width: 100vw;
#             max-height: 100vh;
#             width: auto;
#             height: auto;
#             object-fit: contain;
#             transform-origin: 0 0;
#         }
#         .controls {
# ...

# %% [markdown]
# # Create a matplotlib plot

# %%
fig = plt.figure()
ax = plt.axes()

x = np.arange(0,10)
y = x*x

ax.scatter(x,y)

# %% [markdown]
# # View it in web

# %%
glance.in_web(fig)
# Out:
# 127.0.0.1 - - [21/Jan/2025 08:24:25] "GET / HTTP/1.1" 200 -

# %% [markdown]
# # View it inline

# %%
# Experimental
glance.inline(fig)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Glance</title>
#     <style>
#         body {
#             margin: 0;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh;
#             background: #292929;
#             overflow: hidden;
#         }
#         .zoom-container {
#             height: auto;
#             width: 100vw;
#             position: relative;
#             overflow: hidden;
#             background: #000000;
#             box-shadow: 0 0 10px rgba(0,0,0,0.1);
#             cursor: grab;
#         }
#         .zoom-container:active {
#             cursor: grabbing;
#         }
#         #zoomable-image {
#             display: block;
#             max-width: 100vw;
#             max-height: 100vh;
#             width: auto;
#             height: auto;
#             object-fit: contain;
#             transform-origin: 0 0;
#         }
#         .controls {
# ...
